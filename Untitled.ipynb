# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ##### Get token

# %%
key="L0APMgjVIzasDrKNTl65a8Z9UXVqbkkQo43o7KA3sUvb5ipBuG"
secret="2lY4WRWYVgIYPbXs3XKb3fwGtIsZtIHtBxyx3O1o"
base_url="http://api.petfinder.com/v2/"

# %%
endpoint = 'oauth2/token'

url = base_url+endpoint

data = {
'grant_type': 'client_credentials',
'client_id': key,
'client_secret': secret
}

request = requests.post(url, data=data).json()

accsess_token=request['access_token']

print(accsess_token)
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..Gq7R5gtBNfaYgZ2pzaQXNcJJsmcL0F0T2GSjOY9Md598_gxq-h1_dlvZELKkrYEU5zwLNHwOvcSlol4Y-HB5eXtnPGqUECLt1NQFknhE_gRggiNZ9P3ArIEWMMnWYKERm0SW16ahoBTWPl48Zc5lGL8H8da2pSkccFfbcae7AAGCNR-8LJxz_h64u3qwVVkC8Xtes7CRsQCFE-GBIwLoj3Y6AWcjaFAUppvI_Kg-PkT-ept28GlLwFyVSJmOniovmZf9IB6LFPAqCJDYk-DPn3XnuUpChH9wMhn2ep3ZVLM3bREr_j7n87gBxr7kp4yj4lR9ykDY-Qg1tUV_39w9EA

# %% [markdown]
# ##### Get api

# %%
animal_url="https://api.petfinder.com/v2/animals"
header={
'Authorization': 'Bearer ' + accsess_token}

request=requests.get(animal_url, headers=header).json()

# %%
request
# Out:
# {'animals': [{'id': 48339266,
#    'organization_id': 'NM59',
#    'url': 'https://www.petfinder.com/cat/fran-48339266/nm/albuquerque/animal-humane-new-mexico-nm59/?referrer_id=fe5f174c-1126-457d-93bf-33c59a5a7491',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Fran',
#    'description': 'Hi there! My name is Fran and I am a petite, adorable little lady who cannot wait to be your...',
#    'organization_animal_id': '67690',
#    'photos': [],
# ...

# %%
len(request["animals"])
# Out:
# 20

# %%
request["pagination"]
# Out:
# {'count_per_page': 20,
#  'total_count': 145941,
#  'current_page': 1,
#  'total_pages': 7298,
#  '_links': {'next': {'href': '/v2/animals?page=2'}}}

# %%
animal_url="https://api.petfinder.com/v2/animals"
header={
'Authorization': 'Bearer ' + accsess_token}

request=requests.get(animal_url+'?page=1', headers=header).json()

# %%
request["animals"][0]
# Out:
# {'id': 48339266,
#  'organization_id': 'NM59',
#  'url': 'https://www.petfinder.com/cat/fran-48339266/nm/albuquerque/animal-humane-new-mexico-nm59/?referrer_id=fe5f174c-1126-457d-93bf-33c59a5a7491',
#  'type': 'Cat',
#  'species': 'Cat',
#  'breeds': {'primary': 'Domestic Short Hair',
#   'secondary': None,
#   'mixed': True,
#   'unknown': False},
#  'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#  'age': 'Young',
#  'gender': 'Female',
#  'size': 'Medium',
#  'coat': None,
#  'attributes': {'spayed_neutered': True,
#   'house_trained': False,
#   'declawed': False,
#   'special_needs': False,
#   'shots_current': False},
#  'environment': {'children': None, 'dogs': None, 'cats': None},
#  'tags': [],
#  'name': 'Fran',
#  'description': 'Hi there! My name is Fran and I am a petite, adorable little lady who cannot wait to be your...',
#  'organization_animal_id': '67690',
#  'photos': [],
#  'primary_photo_cropped': None,
#  'videos': [],
# ...

# %%
request["animals"][0]
all animals
all type animals -- bird,cat -- lsit breeds  

all organiation - additional detail about orh=ganiztion
# Out:
#   File "<ipython-input-91-1ce5452487cb>", line 2
#     all animals
#               ^
# SyntaxError: invalid syntax

# %%
animal_url="https://api.petfinder.com/v2/animals?sort=recent"
header={
'Authorization': 'Bearer ' + accsess_token}

request=requests.get(animal_url, headers=header).json()

# %%
request
# Out:
# {'animals': [{'id': 48339266,
#    'organization_id': 'NM59',
#    'url': 'https://www.petfinder.com/cat/fran-48339266/nm/albuquerque/animal-humane-new-mexico-nm59/?referrer_id=fe5f174c-1126-457d-93bf-33c59a5a7491',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Fran',
#    'description': 'Hi there! My name is Fran and I am a petite, adorable little lady who cannot wait to be your...',
#    'organization_animal_id': '67690',
#    'photos': [],
# ...

# %%
animal_url="https://api.petfinder.com/v2/animals"
header={
'Authorization': 'Bearer ' + accsess_token}

request=requests.get(animal_url, headers=header).json()

# %%
request
# Out:
# {'animals': [{'id': 48339608,
#    'organization_id': 'OH19',
#    'url': 'https://www.petfinder.com/dog/ginger-48339608/oh/twinsburg/humane-society-of-summit-county-oh19/?referrer_id=fe5f174c-1126-457d-93bf-33c59a5a7491',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Hound',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Ginger',
#    'description': 'Meet Ginger!This sweet girl is a total dream, she just wants to be around you soaking up all the love...',
#    'organization_animal_id': '37802552',
# ...

# %%
df=pd.DataFrame(request["animals"])

# %%
df.groupby(["size","type"]).count()
# Out:
#                       id  organization_id  url  species  breeds  colors  age  \
# size   type
# Large  Dog             3                3    3        3       3       3    3
# Medium Cat             3                3    3        3       3       3    3
#        Dog             3                3    3        3       3       3    3
#        Small & Furry   3                3    3        3       3       3    3
# Small  Bird            1                1    1        1       1       1    1
#        Cat             5                5    5        5       5       5    5
#        Dog             1                1    1        1       1       1    1
#        Small & Furry   1                1    1        1       1       1    1
#
#                       gender  coat  attributes  ...  organization_animal_id  \
# size   type                                     ...
# Large  Dog                 3     0           3  ...                       3
# ...
